# %%
import numpy as np
import pandas as pd

# %%
test_raw = pd.read_csv('../data/test-no-label-parking.csv', parse_dates = [[3,4]], infer_datetime_format=True)

# %%
test_raw['Minute'] = test_raw.Date_Time.dt.minute
test_raw['Hour'] = test_raw.Date_Time.dt.hour
test_raw['Dow'] = test_raw.Date_Time.dt.weekday

# %%
test_raw['Year'] = test_raw.Date_Time.dt.year
test_raw['Month'] = test_raw.Date_Time.dt.month
def day_type(x):
    if x == 6 or x == 0:
        return 1
    else:
        return 0
test_raw['isweekend'] = test_raw['Dow'].apply(day_type)

# %%
test_raw.head()
# Out:
#             Date_Time           Street                From                 To  \
# 0 2014-03-28 16:34:00  Stockton Street     Stockton Tunnel    Stockton Street
# 1 2014-03-28 21:34:00  Van Ness Avenue        Hayes Street    Van Ness Avenue
# 2 2014-03-28 19:50:00  Van Ness Avenue   McAllister Street    Van Ness Avenue
# 3 2014-03-28 20:02:00   Mission Street         11th Street     Mission Street
# 4 2014-03-28 19:43:00      Hyde Street  Golden Gate Avenue  McAllister Street
#
#    Street.Length  Minute  Hour  Dow  Year  Month  isweekend
# 0      35.786472      34    16    4  2014      3          0
# 1      63.787968      34    21    4  2014      3          0
# 2      56.007236      50    19    4  2014      3          0
# 3     139.651900       2    20    4  2014      3          0
# 4     105.144110      43    19    4  2014      3          0

# %%
train_raw = pd.read_csv('../data/train-parking.csv', parse_dates = [[3,4]], infer_datetime_format=True)
train_raw['Minute'] = train_raw.Date_Time.dt.minute
train_raw['Hour'] = train_raw.Date_Time.dt.hour
train_raw['Dow'] = train_raw.Date_Time.dt.weekday
train_raw['Year'] = train_raw.Date_Time.dt.year
train_raw['Month'] = train_raw.Date_Time.dt.month
train_raw['isweekend'] = train_raw['Dow'].apply(day_type)

# %%
train_raw.groupby(['Hour'])['Date_Time'].count()
# Out:
# Hour
# 7      63
# 8      36
# 9      58
# 10     32
# 11     31
# 12     33
# 13    101
# 14    109
# 15     97
# 16     98
# 17     61
# 18     99
# 19     93
# 20     93
# 21     91
# 22      5
# Name: Date_Time, dtype: int64

# %%
# notice that in test set we have time of 23, which is not present in the train
test_raw.groupby(['Hour'])['Date_Time'].count()
# Out:
# Hour
# 7       6
# 8      48
# 9      51
# 10     73
# 11     76
# 12     23
# 13     21
# 14     37
# 15     29
# 16     43
# 17      3
# 18     26
# 19    102
# 20     92
# 21     72
# 22     20
# 23      4
# Name: Date_Time, dtype: int64

# %%
train_raw.groupby(['Dow'])['Date_Time'].count()
# Out:
# Dow
# 0    179
# 1     94
# 2    112
# 3     91
# 4    229
# 5    284
# 6    111
# Name: Date_Time, dtype: int64

# %%
# notice that we dont even have Sunday on testset - so we won't include sundays in validation set
test_raw.groupby(['Dow'])['Date_Time'].count()
# Out:
# Dow
# 1     54
# 2    248
# 3     38
# 4    194
# 5    120
# 6     72
# Name: Date_Time, dtype: int64

# %%
print('train length: {} test length: {}'.format(train_raw.shape[0], test_raw.shape[0]))
# Out:
# train length: 1100 test length: 726

# %%
train_raw[train_raw['Dow'] != 0].groupby(['Dow'])['Date_Time'].count()/train_raw[train_raw['Dow'] != 0].shape[0]
# Out:
# Dow
# 1    0.102063
# 2    0.121607
# 3    0.098806
# 4    0.248643
# 5    0.308360
# 6    0.120521
# Name: Date_Time, dtype: float64

# %%
test_raw.groupby(['Dow'])['Date_Time'].count()/test_raw.shape[0]
# Out:
# Dow
# 1    0.074380
# 2    0.341598
# 3    0.052342
# 4    0.267218
# 5    0.165289
# 6    0.099174
# Name: Date_Time, dtype: float64

# %%
(train_raw.groupby(['Street'])['Date_Time'].count()-test_raw.groupby(['Street'])['Date_Time'].count()*train_raw.shape[0]/test_raw.shape[0]).astype('int')
# Out:
# Street
# 23rd Street           60
# Battery Street         0
# Bryant Street         11
# Bush Street           -2
# Columbus Avenue       -1
# Geary Street         -14
# Grove Street         -13
# Hyde Street           -5
# Jackson Street         3
# Jessie Street          4
# Jones Street         -34
# Kearny Street        -16
# Larkin Street        -31
# Leavenworth Street    -5
# Mason Street          -7
# Mission Street        34
# Montgomery Street     -7
# Pine Street           15
# Polk Street            0
# Post Street           -1
# Redwood Street        -2
# Stockton Street       -8
# Sutter Street         -6
# Taylor Street        -13
# Van Ness Avenue       23
# Washington Street     19
# Name: Date_Time, dtype: int64

# %% [markdown]
# ### Validation 1: use the same proportion of oberservation by day of week as the test set

# %%
test_prop = test_raw.groupby(['Dow'])['Date_Time'].count()/test_raw.shape[0]

# %%
# assume that we want to have ~250 observations in the validation set, so we will select the following number of rows in the train set for each dow:
n_rows_dow=(test_prop*250).astype('int')

# %%
valid_dow = pd.DataFrame()
for dow, i in zip(n_rows_dow.index, n_rows_dow):
    df_tmp = train_raw[train_raw['Dow']==dow].reset_index()
    rows = np.random.choice(df_tmp.index.values, i, replace=False)
    sampled_df = df_tmp.iloc[rows]
    valid_dow = pd.concat([valid_dow, sampled_df])

# %%
valid_dow.head()
# Out:
#     index           Date_Time             Street             From  \
# 11     32 2014-01-21 19:25:00        23rd Street   Mission Street
# 22    108 2014-01-28 13:56:00  Washington Street  Van Ness Avenue
# 80    927 2014-03-25 15:41:00  Montgomery Street      Verdi Place
# 79    926 2014-03-25 15:04:00  Montgomery Street      Verdi Place
# 76    923 2014-03-25 15:03:00      Kearny Street    Kearny Street
#
#                  To  Real.Spots  Street.Length  any_spot  Minute  Hour  Dow  \
# 11      Capp Street           0      96.040130         0      25    19    1
# 22      Polk Street          26     139.371550         1      56    13    1
# 80   Pacific Avenue           0      66.270280         0      41    15    1
# 79   Pacific Avenue           0      66.270280         0       4    15    1
# 76  Columbus Avenue           0      55.823406         0       3    15    1
#
#     Year  Month  isweekend
# 11  2014      1          0
# 22  2014      1          0
# 80  2014      3          0
# 79  2014      3          0
# 76  2014      3          0

# %%
valid_dow.drop(['index', 'Minute','Hour','Dow','Year','Month','isweekend'], axis=1)
# Out:
#               Date_Time             Street                   From  \
# 11  2014-01-21 19:25:00        23rd Street         Mission Street
# 22  2014-01-28 13:56:00  Washington Street        Van Ness Avenue
# 80  2014-03-25 15:41:00  Montgomery Street            Verdi Place
# 79  2014-03-25 15:04:00  Montgomery Street            Verdi Place
# 89  2014-03-16 07:39:00    Stockton Street           Green Street
# 109 2014-03-23 16:06:00        Polk Street          Bonita Street
# 25  2014-02-02 14:03:00    Van Ness Avenue     Golden Gate Avenue
# 7   2014-02-02 10:27:00      Jessie Street  New Montgomery Street
# 34  2014-02-02 14:29:00    Van Ness Avenue      McAllister Street
# 1   2014-01-26 20:40:00        23rd Street         Mission Street
# 32  2014-02-02 16:30:00    Van Ness Avenue           Hayes Street
# 92  2014-03-16 10:31:00      Kearny Street       Nottingham Place
#
#                         To  Real.Spots  Street.Length  any_spot
# 11             Capp Street           0      96.040130         0
# 22             Polk Street          26     139.371550         1
# 80          Pacific Avenue           0      66.270280         0
# 79          Pacific Avenue           0      66.270280         0
# 76         Columbus Avenue           0      55.823406         0
# 54             Eddy Street           0     104.767970         0
# 48         Columbus Avenue           0      51.843370         0
# 7              Capp Street           1      96.301300         1
# 59          Jackson Street           0      84.282980         0
# 32       Commercial Street           0      50.629986         0
# 42             Maiden Lane           0      52.976276         0
# 36         Merchant Street           0      48.131870         0
# 56            Union Street           2     104.875970         1
# 15       Washington Street           2      98.930230         1
# 16       Washington Street           4      98.983880         1
# 57             Bush Street           0     105.051990         0
# 90         Columbus Avenue           0      51.843370         0
# 58             Bush Street           1     105.051990         1
# 61             Capp Street           2      96.301300         1
# 38          Angelo's Alley           2      26.680704         1
# 49             Bush Street           0      39.027992         0
# 0           Hemlock Street           2      52.505486         1
# 46             Fell Street           0      40.671550         0
# 4    Alice B. Toklas Place           0      52.317448         0
# 7               7th Street          23     276.529660         1
# 83         Columbus Avenue           0      55.823406         0
# 67            Union Street           0     104.875970         0
# 86          Jackson Street           0      28.596806         0
# 16             Post Street           0      52.191193         0
# 45             Fell Street           0      40.671550         0
# ..                     ...         ...            ...       ...
# 60         Van Ness Avenue           2      63.262000         1
# 283           Ellis Street           5      51.088688         1
# 253            Fell Street           0      40.671550         0
# 78             26th Street           0     179.132970         0
# 86            Olive Street           0      52.740210         0
# 7             Geary Street           0      52.188343         0
# 110           Green Street           0      51.765250         0
# 98       Washington Street           5      98.983880         1
# 6              26th Street           1     179.132970         1
# 36             Polk Street           3     146.416550         1
# 108         Vallejo Street           0      53.127136         0
# 105          Larkin Street           0     146.472520         0
# 76         Valencia Street           0      97.607445         0
# 53       Washington Street           0      98.930230         0
# 22             Fell Street           0      40.671550         0
# 58         Van Ness Avenue           0     154.604970         0
# 2          Valencia Street           0      97.607445         0
# 83             Capp Street           1      96.301300         1
# 18            Grove Street           0      52.045720         0
# 33             Post Street           0     104.362960         0
# 40       Washington Street           2      98.408580         1
# 85             17th Street           2     141.702320         1
# 89            Union Street           3     104.875970         1
# 109           Green Street           0      51.765250         0
# 25         Van Ness Avenue           0      63.262000         0
# 7             Annie Street           0      97.182960         0
# 34         Van Ness Avenue           0      56.007236         0
# 1          Bartlett Street           0      96.037110         0
# 32         Van Ness Avenue           6      63.787968         1
# 92                Broadway           0      51.501190         0
#
# [247 rows x 7 columns]

# %% [markdown]
# ### Validation 2: use the same proportion of oberservation by hour_group as the test set

# %%
def hour_group(x):
    if x <= 11:
        return 'morning'
    elif x > 11 and x<=17:
        return  'afternoon'
    else:
        return 'night'

# %%
train_raw['Hour_group'] = train_raw['Hour'].apply(hour_group)
test_raw['Hour_group'] = test_raw['Hour'].apply(hour_group)

# %%
train_raw.head()
# Out:
#             Date_Time           Street                  From             To  \
# 0 2014-01-07 16:19:00   Mission Street           25th Street    26th Street
# 1 2014-01-18 20:42:00      Polk Street          Ellis Street   Olive Street
# 2 2014-01-18 20:39:00  Van Ness Avenue       Geary Boulevard  Myrtle Street
# 3 2014-01-18 20:38:00  Van Ness Avenue           Bush Street    Fern Street
# 4 2014-01-18 20:38:00  Van Ness Avenue  Daniel Burnham Court    Post Street
#
#    Real.Spots  Street.Length  any_spot  Minute  Hour  Dow  Year  Month  \
# 0           4     179.132970         1      19    16    1  2014      1
# 1           0      52.740210         0      42    20    5  2014      1
# 2           0      52.517840         0      39    20    5  2014      1
# 3           0      52.405315         0      38    20    5  2014      1
# 4           0      52.191193         0      38    20    5  2014      1
#
#    isweekend Hour_group
# 0          0  afternoon
# 1          0      night
# 2          0      night
# 3          0      night
# 4          0      night

# %%
test_raw.groupby(['Hour_group'])['Date_Time'].count()/test_raw.shape[0]
# Out:
# Hour_group
# afternoon    0.214876
# morning      0.349862
# night        0.435262
# Name: Date_Time, dtype: float64

# %%
train_raw.groupby(['Hour_group'])['Date_Time'].count()/train_raw.shape[0]
# Out:
# Hour_group
# afternoon    0.453636
# morning      0.200000
# night        0.346364
# Name: Date_Time, dtype: float64

# %%
test_prop_hg = test_raw.groupby(['Hour_group'])['Date_Time'].count()/test_raw.shape[0]

# assume that we want to have ~250 observations in the validation set, so we will select the following number of rows in the train set for each dow:
n_rows_hg=(test_prop_hg*250).astype('int')

# %%
valid_hg = pd.DataFrame()
for hg, i in zip(n_rows_hg.index, n_rows_hg):
    df_tmp = train_raw[train_raw['Hour_group']==hg].reset_index()
    rows = np.random.choice(df_tmp.index.values, i, replace=False)
    sampled_df = df_tmp.iloc[rows]
    valid_hg = pd.concat([valid_hg, sampled_df])

# %%
valid_hg.groupby(['Hour_group'])['Date_Time'].count()/valid_hg.shape[0]
# Out:
# Hour_group
# afternoon    0.213710
# morning      0.350806
# night        0.435484
# Name: Date_Time, dtype: float64

# %%
valid_hg.drop(['index', 'Minute','Hour','Dow','Year','Month','isweekend','Hour_group'], axis=1)
# Out:
#               Date_Time              Street                   From  \
# 30  2014-01-27 16:57:00         Pine Street          Larkin Street
# 469 2014-03-27 15:51:00   Montgomery Street      Montgomery Street
# 5   2014-01-21 17:35:00         23rd Street         Mission Street
# 424 2014-03-26 16:06:00     Stockton Street        Stockton Street
# 240 2014-02-11 13:13:00     Columbus Avenue          Kearny Street
# 157 2014-02-03 16:04:00     Van Ness Avenue      McAllister Street
# 236 2014-02-11 13:21:00   Montgomery Street            Bush Street
# 353 2014-03-22 13:01:00     Van Ness Avenue        Van Ness Avenue
# 190 2014-02-03 13:03:00       Larkin Street            Turk Street
# 387 2014-03-23 17:11:00   Washington Street            Polk Street
# 303 2014-03-23 18:13:00     Van Ness Avenue            Clay Street
# 152 2014-03-15 20:54:00       Larkin Street           Cedar Street
#
#                         To  Real.Spots  Street.Length  any_spot Hour_group
# 30             Polk Street           0     146.416550         0  afternoon
# 469         Jackson Street           0      28.596806         0  afternoon
# 5          Bartlett Street           1      96.037110         1  afternoon
# 424         Jackson Street           0      84.282980         0  afternoon
# 240         Pacific Avenue           0      28.695284         0  afternoon
# 157        Van Ness Avenue           0     154.604970         0  afternoon
# 236          Sutter Street           0     105.384210         0  afternoon
# 353            Bush Street           4      39.027992         1  afternoon
# 190            Eddy Street           0     104.799670         0  afternoon
# 387          Larkin Street           0     146.472520         0  afternoon
# 75           Myrtle Street           0      52.517840         0  afternoon
# 252      Montgomery Street           0      51.695087         0  afternoon
# 454      Commercial Street           0      50.629986         0  afternoon
# 155           Grove Street           0      52.045720         0  afternoon
# 94         Van Ness Avenue           1     139.323970         1  afternoon
# 136           Geary Street           5     109.843506         1  afternoon
# 355          Larkin Street           0      48.555763         0  afternoon
# 437               Broadway           3     104.314545         1  afternoon
# 9          Bartlett Street           1      96.037110         1  afternoon
# 39         Van Ness Avenue           2     139.323970         1  afternoon
# 96          Vallejo Street           0      53.127136         0  afternoon
# 52             Polk Street           1     139.371550         1  afternoon
# 82             Bush Street           0      39.027992         0  afternoon
# 435        Van Ness Avenue           0      56.007236         0  afternoon
# 119            Fell Street           0      40.671550         0  afternoon
# 186           Geary Street           0     104.987540         0  afternoon
# 464         Jackson Street           0      84.282980         0  afternoon
# 7              Capp Street           0      96.040130         0  afternoon
# 396         Jackson Street           0      28.596806         0  afternoon
# 66         Van Ness Avenue           0     139.494200         0  afternoon
# ..                     ...         ...            ...       ...        ...
# 121         Vallejo Street           0      53.127136         0      night
# 246            Polk Street           0     146.416550         0      night
# 20             Capp Street           1      96.301300         1      night
# 38            Mason Street           1     146.525740         1      night
# 347             Elm Street           0      52.597584         0      night
# 77           Austin Street           0      52.384674         0      night
# 233  Alice B. Toklas Place           0      52.317448         0      night
# 112               Broadway           1     104.314545         1      night
# 1            Myrtle Street           0      52.517840         0      night
# 357            Bush Street           0     105.051990         0      night
# 0             Olive Street           0      52.740210         0      night
# 314        Columbus Avenue           0      51.843370         0      night
# 145  Alice B. Toklas Place           0      52.317448         0      night
# 68           Sutter Street           0     103.210660         0      night
# 304            Polk Street           6     146.416550         1      night
# 41         Van Ness Avenue           4     139.494200         1      night
# 162          Larkin Street           4      52.413400         1      night
# 222          Sutter Street           0     105.384210         0      night
# 63           Chatham Place           0      41.920464         0      night
# 363           Geary Street           1      52.188343         1      night
# 66             Bush Street           0     105.051990         0      night
# 84             17th Street           6     141.702320         1      night
# 274            Bush Street           0      39.027992         0      night
# 169            Hyde Street           0     146.586320         0      night
# 300           Ellis Street           0      51.088688         0      night
# 329           Ellis Street           2     104.763840         1      night
# 307           Green Street           0      51.765250         0      night
# 308           Union Street           0     104.875970         0      night
# 303      Washington Street           0      98.930230         0      night
# 152            Post Street           0      52.324250         0      night
#
# [248 rows x 8 columns]
